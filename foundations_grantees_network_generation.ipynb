# %% [markdown]
# ## Foundations and Grantees Network Generation

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import altair as alt
import seaborn as sns

# %% [markdown]
# Read in data -- original is https://indiana-my.sharepoint.com/:x:/r/personal/fulton_iu_edu/Documents/Funder-Grantee%20Network/Data/2019%20Data%20for%20Visualizations%20and%20Network%20Analyses/2019%20Matches%20for%20Data%20Visualizations%20and%20Network%20Analyses_2022.9.29.xlsx?d=w157b25b52b5c46edaabd7ad48ad31177&csf=1&web=1&e=N4wcXo
# "2019 Matches for Data Visualizations and Network Analyses_2022.9.29"
#
# **Suggested to download as CSV
#
# Each row of this datasource denotes a funding action from a foundation to a grantee.

# %%
foundations_raw_all = pd.read_csv("/Users/lelee1/Desktop/D592/Foundations/2019 Matches for Data Visualizations and Network Analyses_2022.9.29.csv")
print(foundations_raw_all.shape)
foundations_raw_all.head()
# Out:
# /var/folders/lh/tw7lgns53bsgp8s5xtzzd4rw0000gp/T/ipykernel_12630/3964066189.py:1: DtypeWarning: Columns (25,29,99,100,102,104,105,116,117) have mixed types. Specify dtype option on import or set low_memory=False.
#   foundations_raw_all = pd.read_csv("/Users/lelee1/Desktop/D592/Foundations/2019 Matches for Data Visualizations and Network Analyses_2022.9.29.csv")
# (558319, 120)
#     Amount Grantee City Grantee City_grantee  \
# 0  10000.0      hanover              hanover
# 1   2550.0       gorham               gorham
# 2  10000.0      lebanon              lebanon
# 3   5000.0      lebanon              lebanon
# 4   5000.0      lebanon              lebanon
#
#                               Grantee Name  \
# 0     hampshire cooperative nursery school
# 1  north country education services agency
# 2   friends of norris cotton cancer center
# 3   friends of norris cotton cancer center
# 4   friends of norris cotton cancer center
#
#                       Grantee Name_grantee Grantee State  \
# 0     hampshire cooperative nursery school            nh
# 1  north country education services agency            nh
# 2   friends of norris cotton cancer center            nh
# 3   friends of norris cotton cancer center            nh
# 4   friends of norris cotton cancer center            nh
#
#   Grantee State_grantee  Grantee Zip Match Type ntee_full2  ...  \
# 0                    nh       3755.0  Exact Zip        T20  ...
# 1                    nh       3581.0  Exact Zip        T20  ...
# 2                    nh       3756.0  Exact Zip        T20  ...
# 3                    nh       3756.0  Exact Zip        T20  ...
# 4                    nh       3756.0  Exact Zip        T20  ...
#
#    f_amt_assets_total_boy  f_amt_assets_total_3 f_amt_liabilities_total_boy  \
# 0              46182976.0            75610714.0                      7618.0
# 1              46182976.0            75610714.0                      7618.0
# 2              46182976.0            75610714.0                      7618.0
# 3              46182976.0            75610714.0                      7618.0
# 4              46182976.0            75610714.0                      7618.0
#
#    f_amt_liabilities_total  f_amt_assets_net f_amt_assets_net_2  \
# 0                      0.0        75610714.0         75610714.0
# 1                      0.0        75610714.0         75610714.0
# 2                      0.0        75610714.0         75610714.0
# 3                      0.0        75610714.0         75610714.0
# 4                      0.0        75610714.0         75610714.0
#
#   f_operating_fdtn  f_operating_fdtn_2 f_website_address f_amt_assets_total_2
# 0            False               False               NaN                  0.0
# 1            False               False               NaN                  0.0
# 2            False               False               NaN                  0.0
# 3            False               False               NaN                  0.0
# 4            False               False               NaN                  0.0
#
# [5 rows x 120 columns]

# %%
## Rename columns to be uniform format -- lowercase & no spaces
foundations_raw_all.columns = ["_".join(x.split(" ")).lower() for x in foundations_raw_all.columns.tolist()]
foundations_raw_all.head()
# Out:
#     amount grantee_city grantee_city_grantee  \
# 0  10000.0      hanover              hanover
# 1   2550.0       gorham               gorham
# 2  10000.0      lebanon              lebanon
# 3   5000.0      lebanon              lebanon
# 4   5000.0      lebanon              lebanon
#
#                               grantee_name  \
# 0     hampshire cooperative nursery school
# 1  north country education services agency
# 2   friends of norris cotton cancer center
# 3   friends of norris cotton cancer center
# 4   friends of norris cotton cancer center
#
#                       grantee_name_grantee grantee_state  \
# 0     hampshire cooperative nursery school            nh
# 1  north country education services agency            nh
# 2   friends of norris cotton cancer center            nh
# 3   friends of norris cotton cancer center            nh
# 4   friends of norris cotton cancer center            nh
#
#   grantee_state_grantee  grantee_zip match_type ntee_full2  ...  \
# 0                    nh       3755.0  Exact Zip        T20  ...
# 1                    nh       3581.0  Exact Zip        T20  ...
# 2                    nh       3756.0  Exact Zip        T20  ...
# 3                    nh       3756.0  Exact Zip        T20  ...
# 4                    nh       3756.0  Exact Zip        T20  ...
#
#    f_amt_assets_total_boy  f_amt_assets_total_3 f_amt_liabilities_total_boy  \
# 0              46182976.0            75610714.0                      7618.0
# 1              46182976.0            75610714.0                      7618.0
# 2              46182976.0            75610714.0                      7618.0
# 3              46182976.0            75610714.0                      7618.0
# 4              46182976.0            75610714.0                      7618.0
#
#    f_amt_liabilities_total  f_amt_assets_net f_amt_assets_net_2  \
# 0                      0.0        75610714.0         75610714.0
# 1                      0.0        75610714.0         75610714.0
# 2                      0.0        75610714.0         75610714.0
# 3                      0.0        75610714.0         75610714.0
# 4                      0.0        75610714.0         75610714.0
#
#   f_operating_fdtn  f_operating_fdtn_2 f_website_address f_amt_assets_total_2
# 0            False               False               NaN                  0.0
# 1            False               False               NaN                  0.0
# 2            False               False               NaN                  0.0
# 3            False               False               NaN                  0.0
# 4            False               False               NaN                  0.0
#
# [5 rows x 120 columns]

# %%
# Create separate foundation & grantee dataframes from edgelist -- 
grantees = foundations_raw_all[['ein',
 'g_business_name',
 'g_ntee_full',
 'g_name_990',
 'g_name_line2_990',
 'g_formation_yr_990',
 'g_country_990',
 'g_city_990',
 'g_state_990',
 'g_zipcode_990',
 'g_taxexempt_type',
 'g_website_address_990',
 'g_amt_exp_total',
 'g_amt_assets_total',
 'g_amt_rev_total',
 'g_amt_rev_contrib_total',
 'g_num_volunteers']].rename(columns = {'ein':'ein',
 'g_business_name':'name',
 'g_ntee_full':'ntee',
 'g_name_990':'g_name_990',
 'g_name_line2_990':'g_name_line2_990',
 'g_formation_yr_990':'formation_yr',
 'g_country_990':'country',
 'g_city_990':'city',
 'g_state_990':'state',
 'g_zipcode_990':'zip',
 'g_taxexempt_type':'taxexempt_type',
 'g_website_address_990':'website',
 'g_amt_exp_total':'amt_exp_total',
 'g_amt_assets_total':'amt_assets_total',
 'g_amt_rev_total':'amt_rev_total',
 'g_amt_rev_contrib_total':'amt_rev_contrib_total',
 'g_num_volunteers':'num_volunteers'})

grantees.insert(0,'entity_type', 'grantee')

foundations = foundations_raw_all[[
 'foundation_ein',
 'f_business_name',
 'f_ntee_full',
 'f_city',
 'f_state',
 'f_zip',
 'f_website_address',
 'f_amt_exp_total',
 'f_amt_assets_total',
 'f_amt_rev_total']].rename(columns = {'foundation_ein':'ein',
 'f_business_name':'name',
 'f_ntee_full':'ntee',
 'f_city':'city',
 'f_state':'state',
 'f_zip':'zip',
 'f_website_address':'website',
 'f_amt_exp_total':'amt_exp_total',
 'f_amt_assets_total':'amt_assets_total',
 'f_amt_rev_total':'amt_rev_total'})
 
foundations.insert(0,'entity_type', 'foundation')

# %% [markdown]
# We need to get information about each entity to assign in the network representation, and thus need to pivot the wide-form raw data into a long-form unique attribute dataframe

# %%
# Concatenate foundations & grantees into a total entity dataframe
all_entities = pd.concat([grantees, foundations], ignore_index = True).drop_duplicates()

# Examine entries that demonstrate the same EIN but different attributes
all_entities.groupby(['ein']).filter(lambda x: len(x) > 1).sort_values('ein')
# Out:
#         entity_type        ein  \
# 300         grantee   10211565
# 639         grantee   10211565
# 684         grantee   10278395
# 208         grantee   10278395
# 194748      grantee   10280225
# ...             ...        ...
# 1109834  foundation  954692410
# 151005      grantee  954804431
# 1110899  foundation  954804431
# 187559      grantee  990268061
# 1116120  foundation  990268061
#
#                                                    name ntee g_name_990  \
# 300                                    Waynflete School  B20        NaN
# 639                                                 NaN  NaN        NaN
# 684                           Woodfords Family Services  B28        NaN
# 208                                                 NaN  NaN        NaN
# 194748                                              NaN  NaN        NaN
# ...                                                 ...  ...        ...
# 1109834  Terasaki Nibei Foundation Fka Nibei Foundation  T20        NaN
# 151005                                              NaN  NaN        NaN
# 1110899                         The Lawrence Foundation  T20        NaN
# 187559                                              NaN  NaN        NaN
# 1116120          Harriet Bouslog Labor Scholarship Fund  B82        NaN
#
#         g_name_line2_990  formation_yr country          city state      zip  \
# 300                  NaN        1935.0     NaN      Portland    ME   4102.0
# 639                  NaN           NaN     NaN           NaN   NaN      NaN
# 684                  NaN        1977.0     NaN     Westbrook    ME   4092.0
# 208                  NaN           NaN     NaN           NaN   NaN      NaN
# 194748               NaN           NaN     NaN           NaN   NaN      NaN
# ...                  ...           ...     ...           ...   ...      ...
# 1109834              NaN           NaN     NaN   Los Angeles    CA  90024.0
# 151005               NaN           NaN     NaN           NaN   NaN      NaN
# 1110899              NaN           NaN     NaN  Santa Monica    CA  90408.0
# 187559               NaN           NaN     NaN           NaN   NaN      NaN
# 1116120              NaN           NaN     NaN      Honolulu    HI  96813.0
#
#         taxexempt_type                        website  amt_exp_total  \
# 300              False              Www.Waynflete.Org     21123544.0
# 639                NaN                            NaN            NaN
# 684              False                  Woodfords.Org     31196565.0
# 208                NaN                            NaN            NaN
# 194748             NaN                            NaN            NaN
# ...                ...                            ...            ...
# 1109834            NaN             terasaki.org/nibei        80841.0
# 151005             NaN                            NaN            NaN
# 1110899            NaN  www.thelawrencefoundation.org       310005.0
# 187559             NaN                            NaN            NaN
# 1116120            NaN                            NaN       203174.0
#
#          amt_assets_total  amt_rev_total  amt_rev_contrib_total  \
# 300            56687644.0     20348490.0              1273174.0
# 639                   NaN            NaN                    NaN
# 684             9157848.0     28585212.0               368291.0
# 208                   NaN            NaN                    NaN
# 194748                NaN            NaN                    NaN
# ...                   ...            ...                    ...
# 1109834         6040712.0      6112989.0                    NaN
# 151005                NaN            NaN                    NaN
# 1110899         3855161.0       287504.0                    NaN
# 187559                NaN            NaN                    NaN
# 1116120         2820542.0       493444.0                    NaN
#
#          num_volunteers
# 300                50.0
# 639                 NaN
# 684                11.0
# 208                 NaN
# 194748              NaN
# ...                 ...
# 1109834             NaN
# 151005              NaN
# 1110899             NaN
# 187559              NaN
# 1116120             NaN
#
# [1846 rows x 18 columns]

# %% [markdown]
# Utilize EIN as a unique identifier for each entity.

# %%
# Aggregate all entity attributes into sets (unique values)
all_entities_grouped = all_entities.astype(str).groupby(['ein']).agg(set).reset_index()
all_entities_grouped.head()
# Out:
#          ein   entity_type                                               name  \
# 0          1     {grantee}                                              {nan}
# 1  100000085     {grantee}      {Greater Rochester Enterprise Foundation Inc}
# 2  100000573  {foundation}  {The Couch Family Foundation C/O Mott Philanth...
# 3  100000800     {grantee}                                              {nan}
# 4  100002102     {grantee}                       {Everybody Wins Vermont Inc}
#
#     ntee g_name_990 g_name_line2_990 formation_yr country          city  \
# 0  {nan}      {nan}            {nan}        {nan}   {nan}         {nan}
# 1  {S31}      {nan}            {nan}     {2002.0}   {nan}   {Rochester}
# 2  {T20}      {nan}            {nan}        {nan}   {nan}      {Boston}
# 3  {nan}      {nan}            {nan}        {nan}   {nan}         {nan}
# 4  {O50}      {nan}            {nan}     {2001.0}   {nan}  {Montpelier}
#
#    state        zip taxexempt_type                         website  \
# 0  {nan}      {nan}          {nan}                           {nan}
# 1   {NY}  {14604.0}        {False}          {Www.Rochesterbiz.Com}
# 2   {MA}   {2199.0}          {nan}                           {nan}
# 3  {nan}      {nan}          {nan}                           {nan}
# 4   {VT}   {5601.0}        {False}  {Www.Everybodywinsvermont.Org}
#
#   amt_exp_total amt_assets_total amt_rev_total amt_rev_contrib_total  \
# 0         {nan}            {nan}         {nan}                 {nan}
# 1   {1607806.0}       {196436.0}   {1497294.0}           {1497001.0}
# 2   {3294710.0}     {94849383.0}  {34816817.0}                 {nan}
# 3         {nan}            {nan}         {nan}                 {nan}
# 4    {314926.0}        {50647.0}    {232940.0}            {232249.0}
#
#   num_volunteers
# 0          {nan}
# 1         {44.0}
# 2          {nan}
# 3          {nan}
# 4        {600.0}

# %%
# Iterate through attribute columns & get unique, non-null values from the sets
for c in all_entities_grouped.columns.tolist()[1:]:
    all_entities_grouped[c] = all_entities_grouped[c].apply(lambda x: [i for i in x if i != 'nan'][0] if len([i for i in x if i != 'nan']) == 1 else (np.nan if len([i for i in x if i != 'nan']) == 0 else [i for i in x if i != 'nan']))

all_entities_grouped = all_entities_grouped.astype(all_entities.dtypes.to_dict()).astype({'entity_type':str})

# %%
all_entities_grouped.groupby(['ein']).filter(lambda x: len(x) > 1)
# Out:
# Empty DataFrame
# Columns: [ein, entity_type, name, ntee, g_name_990, g_name_line2_990, formation_yr, country, city, state, zip, taxexempt_type, website, amt_exp_total, amt_assets_total, amt_rev_total, amt_rev_contrib_total, num_volunteers]
# Index: []

# %% [markdown]
# there now aren't any conflicting attribute assignments

# %%
# Create an edgelist for networkx
edgelist = foundations_raw_all[['amount','ein','foundation_ein']]

# %%
# Construct networkx graph
Graph_f_g = nx.from_pandas_edgelist(edgelist, source = 'foundation_ein', target='ein',edge_attr=['amount'], create_using=nx.DiGraph())

# %%
# Set node attributes
ent_props = all_entities_grouped.drop_duplicates().reset_index(drop = True)
xattrs = {}
for x,row in ent_props.set_index('ein').iterrows():
    xattrs[x] = row.dropna().to_dict()
# xattrs = ent_props.set_index('ein').to_dict('index')
nx.set_node_attributes(Graph_f_g, pd.Series(xattrs))

# %%
# Get network summary info
nx.info(Graph_f_g)
# Out:
# /var/folders/lh/tw7lgns53bsgp8s5xtzzd4rw0000gp/T/ipykernel_12630/3841826930.py:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(Graph_f_g)
# 'DiGraph with 187181 nodes and 502456 edges'

# %%
# Write gml file
nx.write_gml(Graph_f_g, path = '/Users/lelee1/Desktop/D592/Foundations/foundations_grantees_network.gml')
